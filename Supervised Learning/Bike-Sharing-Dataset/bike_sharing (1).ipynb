# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.9 GB  | Proc size: 120.0 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
# !kill -9 -1

# %%
import pandas as p
import numpy as n

# %%
from google.colab import files
files.upload()

# %%
d = p.read_csv("day.csv")
h = p.read_csv("hour.csv")
d.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0        1  2011-01-01       1   0  ...   0.160446     331         654   985
# 1        2  2011-01-02       1   0  ...   0.248539     131         670   801
# 2        3  2011-01-03       1   0  ...   0.248309     120        1229  1349
# 3        4  2011-01-04       1   0  ...   0.160296     108        1454  1562
# 4        5  2011-01-05       1   0  ...   0.186900      82        1518  1600
#
# [5 rows x 16 columns]

# %%
h.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0  ...        0.0       3          13   16
# 1        2  2011-01-01       1   0  ...        0.0       8          32   40
# 2        3  2011-01-01       1   0  ...        0.0       5          27   32
# 3        4  2011-01-01       1   0  ...        0.0       3          10   13
# 4        5  2011-01-01       1   0  ...        0.0       0           1    1
#
# [5 rows x 17 columns]

# %%
h.shape
h.holiday.value_counts()
# Out:
# 0    16879
# 1      500
# Name: holiday, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as p
for i in ["temp","atemp","hum","windspeed","casual","registered"]:
    p.scatter(d[i],d.cnt)
    p.xlabel(i)
    p.ylabel("count")
    p.show()

# %%
d.describe()
# Out:
#           instant      season  ...   registered          cnt
# count  731.000000  731.000000  ...   731.000000   731.000000
# mean   366.000000    2.496580  ...  3656.172367  4504.348837
# std    211.165812    1.110807  ...  1560.256377  1937.211452
# min      1.000000    1.000000  ...    20.000000    22.000000
# 25%    183.500000    2.000000  ...  2497.000000  3152.000000
# 50%    366.000000    3.000000  ...  3662.000000  4548.000000
# 75%    548.500000    3.000000  ...  4776.500000  5956.000000
# max    731.000000    4.000000  ...  6946.000000  8714.000000
#
# [8 rows x 15 columns]

# %%
d.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
d['cnt'].shape
# Out:
# (731,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
trainX,testX,trainY,testY =  train_test_split(d[['temp','atemp','hum','windspeed','casual',
                                                           'registered']],d['cnt'],test_size=0.33,random_state=42)
model1 = LinearRegression()
model1.fit(trainX,trainY)
pred1=model1.predict(testX)
from sklearn.metrics import mean_squared_error,r2_score
m = mean_squared_error(testY,pred1)
m
# Out:
# 3.1730227798423175e-24

# %%
r= r2_score(testY,pred1)
r
# Out:
# 1.0

# %%
c = [i for i in range(0,242,1)]
fig = p.figure()
p.plot(c,testY, color="red", linewidth=3,)
p.plot(c,pred1, color="yellow",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=30)              # Plot heading 
p.xlabel('Index', fontsize=20)                               # X-label
p.ylabel('PRICE', fontsize=18)
# Out:
# Text(0, 0.5, 'PRICE')
